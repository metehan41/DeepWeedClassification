# %%
DATA_DIR = '/content/drive/MyDrive/WeedClassification/data/weeds3'

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 10.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO


model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 5.28M/5.28M [00:00<00:00, 73.9MB/s]

# %%
# Train the model
results = model.train(data=DATA_DIR, epochs=20, imgsz=64)
# Out:
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs/classify/train2 '/content/drive/MyDrive/WeedClassification/runs/classify/train4'

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


results_path = '/content/runs/classify/train2/results.csv'

results = pd.read_csv(results_path)


plt.figure()
plt.plot(results['                  epoch'], results['             train/loss'], label='train loss')
plt.plot(results['                  epoch'], results['               val/loss'], label='val loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()


plt.figure()
plt.plot(results['                  epoch'], results['  metrics/accuracy_top1'] * 100)
plt.grid()
plt.title('Validation accuracy vs epochs')
plt.ylabel('accuracy (%)')
plt.xlabel('epochs')

plt.show()

# %%
model = YOLO('/content/runs/classify/train2/weights/best.pt') # load a pretrained model (recommended for training)
# Resume training
model.to ('cuda:0')
model.train(data=DATA_DIR, epochs=10, resume=True, imgsz=64,device='cuda:0')
# Out:
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs/classify/train '/content/drive/MyDrive/WeedClassification/runs/classify/train5'

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


results_path = '/content/runs/classify/train24/results.csv'

results = pd.read_csv(results_path)


plt.figure()
plt.plot(results['                  epoch'], results['             train/loss'], label='train loss')
plt.plot(results['                  epoch'], results['               val/loss'], label='val loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()


plt.figure()
plt.plot(results['                  epoch'], results['  metrics/accuracy_top1'] * 100)
plt.grid()
plt.title('Validation accuracy vs epochs')
plt.ylabel('accuracy (%)')
plt.xlabel('epochs')

plt.show()

# %%
# !scp -r /content/runs/classify/train24 '/content/drive/MyDrive/WeedClassification/runs/classify/train6'
